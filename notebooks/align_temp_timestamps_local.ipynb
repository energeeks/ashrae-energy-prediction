# %%
from os.path import join as pjoin
import numpy as np
import pandas as pd
from datetime import datetime
from pytz import timezone
import pytz

# %%
RAW_DATA_DIR = "../data/raw"

print('Loading init weather data...')
# load and concatenate weather data
weather_dtypes = {
    'site_id': np.uint8,
    'air_temperature': np.float32,
    'cloud_coverage': np.float32,
    'dew_temperature': np.float32,
    'precip_depth_1_hr': np.float32,
    'sea_level_pressure': np.float32,
    'wind_direction': np.float32,
    'wind_speed': np.float32,
}

weather_train = pd.read_csv(
    pjoin(RAW_DATA_DIR, 'weather_train.csv'),
    dtype=weather_dtypes,
    parse_dates=['timestamp']
)
weather_test = pd.read_csv(
    pjoin(RAW_DATA_DIR, 'weather_test.csv'),
    dtype=weather_dtypes,
    parse_dates=['timestamp']
)

weather = pd.concat(
    [
        weather_train,
        weather_test
    ],
    ignore_index=True
)
# del redundant dfs
del weather_train, weather_test
# Out:
# Loading init weather data...

# %%
weather.head()
# Out:
#    site_id           timestamp  air_temperature  cloud_coverage  \
# 0        0 2016-01-01 00:00:00        25.000000             6.0
# 1        0 2016-01-01 01:00:00        24.400000             NaN
# 2        0 2016-01-01 02:00:00        22.799999             2.0
# 3        0 2016-01-01 03:00:00        21.100000             2.0
# 4        0 2016-01-01 04:00:00        20.000000             2.0
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0             20.0                NaN         1019.700012             0.0
# 1             21.1               -1.0         1020.200012            70.0
# 2             21.1                0.0         1020.200012             0.0
# 3             20.6                0.0         1020.099976             0.0
# 4             20.0               -1.0         1020.000000           250.0
#
#    wind_speed
# 0         0.0
# 1         1.5
# 2         0.0
# 3         0.0
# 4         2.6

# %%
site_info = pd.read_csv('../data/site_info.csv', delimiter = ";")
site_info
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-27afb32d343b> in <module>()
# ----> 1 site_info = pd.read_csv('../data/site_info.csv', delimiter = ";")
#       2 site_info
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas\_libs\parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas\_libs\parsers.c:8873)()
#
# FileNotFoundError: File b'../data/site_info.csv' does not exist

# %%
weather = weather.merge(site_info, on = "site_id", how = "left")

# %%
weather.head()
# Out:
#    site_id           timestamp  air_temperature  cloud_coverage  \
# 0        0 2016-01-01 00:00:00        25.000000             6.0
# 1        0 2016-01-01 01:00:00        24.400000             NaN
# 2        0 2016-01-01 02:00:00        22.799999             2.0
# 3        0 2016-01-01 03:00:00        21.100000             2.0
# 4        0 2016-01-01 04:00:00        20.000000             2.0
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0             20.0                NaN         1019.700012             0.0
# 1             21.1               -1.0         1020.200012            70.0
# 2             21.1                0.0         1020.200012             0.0
# 3             20.6                0.0         1020.099976             0.0
# 4             20.0               -1.0         1020.000000           250.0
#
#    wind_speed    timezone country_code     location
# 0         0.0  US/Eastern           US  Orlando, FL
# 1         1.5  US/Eastern           US  Orlando, FL
# 2         0.0  US/Eastern           US  Orlando, FL
# 3         0.0  US/Eastern           US  Orlando, FL
# 4         2.6  US/Eastern           US  Orlando, FL

# %%
# define a time format
fmt = '%Y-%m-%d %H:%M:%S %Z%z'
# time object
utc = pytz.utc

# %%
utc.localize(weather.timestamp[1])
# Out:
# Timestamp('2016-01-01 01:00:00+0000', tz='UTC')

# %%
# bring all timestamps into utc timeformat
weather['timestamp'] = weather.timestamp.apply(lambda x: utc.localize(x))

# %%
weather.head()
# Out:
#    site_id                 timestamp  air_temperature  cloud_coverage  \
# 0        0 2016-01-01 00:00:00+00:00        25.000000             6.0
# 1        0 2016-01-01 01:00:00+00:00        24.400000             NaN
# 2        0 2016-01-01 02:00:00+00:00        22.799999             2.0
# 3        0 2016-01-01 03:00:00+00:00        21.100000             2.0
# 4        0 2016-01-01 04:00:00+00:00        20.000000             2.0
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0             20.0                NaN         1019.700012             0.0
# 1             21.1               -1.0         1020.200012            70.0
# 2             21.1                0.0         1020.200012             0.0
# 3             20.6                0.0         1020.099976             0.0
# 4             20.0               -1.0         1020.000000           250.0
#
#    wind_speed    timezone country_code     location
# 0         0.0  US/Eastern           US  Orlando, FL
# 1         1.5  US/Eastern           US  Orlando, FL
# 2         0.0  US/Eastern           US  Orlando, FL
# 3         0.0  US/Eastern           US  Orlando, FL
# 4         2.6  US/Eastern           US  Orlando, FL

# %%
weather['timezone'] = weather.timezone.apply(lambda x: timezone(x))

# %%
weather['timestamp_local'] = weather.apply(lambda x: x.timestamp.astimezone(x.timezone), axis = 1)

# %%
weather.head()
# Out:
#    site_id                 timestamp  air_temperature  cloud_coverage  \
# 0        0 2016-01-01 00:00:00+00:00        25.000000             6.0
# 1        0 2016-01-01 01:00:00+00:00        24.400000             NaN
# 2        0 2016-01-01 02:00:00+00:00        22.799999             2.0
# 3        0 2016-01-01 03:00:00+00:00        21.100000             2.0
# 4        0 2016-01-01 04:00:00+00:00        20.000000             2.0
#
#    dew_temperature  precip_depth_1_hr  sea_level_pressure  wind_direction  \
# 0             20.0                NaN         1019.700012             0.0
# 1             21.1               -1.0         1020.200012            70.0
# 2             21.1                0.0         1020.200012             0.0
# 3             20.6                0.0         1020.099976             0.0
# 4             20.0               -1.0         1020.000000           250.0
#
#    wind_speed    timezone country_code     location            timestamp_local
# 0         0.0  US/Eastern           US  Orlando, FL  2015-12-31 19:00:00-05:00
# 1         1.5  US/Eastern           US  Orlando, FL  2015-12-31 20:00:00-05:00
# 2         0.0  US/Eastern           US  Orlando, FL  2015-12-31 21:00:00-05:00
# 3         0.0  US/Eastern           US  Orlando, FL  2015-12-31 22:00:00-05:00
# 4         2.6  US/Eastern           US  Orlando, FL  2015-12-31 23:00:00-05:00

# %%
weather.timestamp_local[1] == pd.Timestamp('2015-12-31 20:00:00-0500', tz='US/Eastern')
# Out:
# True

# %%
weather.timestamp_local == pd.Timestamp('2015-12-31 20:00:00-0500', tz='US/Eastern')
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 417011    False
# 417012    False
# 417013    False
# 417014    False
# 417015    False
# Name: timestamp_local, Length: 417016, dtype: bool

# %%
k = weather.timestamp_local == pd.Timestamp('2016-03-13 03:00:00-0400', tz='US/Eastern')

# %%
weather.loc[k,]
# Out:
#         site_id                 timestamp  air_temperature  cloud_coverage  \
# 1735          0 2016-03-13 07:00:00+00:00             20.0             NaN
# 10508         1 2016-03-13 07:00:00+00:00              3.4             NaN
# 19282         2 2016-03-13 07:00:00+00:00             15.6             0.0
# 28065         3 2016-03-13 07:00:00+00:00             12.8             NaN
# 36844         4 2016-03-13 07:00:00+00:00             13.9             NaN
# 45614         5 2016-03-13 07:00:00+00:00              7.0             NaN
# 54382         6 2016-03-13 07:00:00+00:00             15.0             0.0
# 63060         7 2016-03-13 07:00:00+00:00              4.2             NaN
# 71779         8 2016-03-13 07:00:00+00:00             20.0             NaN
# 80562         9 2016-03-13 07:00:00+00:00             14.4             0.0
# 89342        10 2016-03-13 07:00:00+00:00              5.0             0.0
# 98020        11 2016-03-13 07:00:00+00:00              4.2             NaN
# 106729       12 2016-03-13 07:00:00+00:00              8.0             7.0
# 115494       13 2016-03-13 07:00:00+00:00             10.0             NaN
# 124276       14 2016-03-13 07:00:00+00:00              9.4             0.0
# 132955       15 2016-03-13 07:00:00+00:00              7.8             0.0
#
#         dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# 1735          16.700001                0.0         1017.299988
# 10508          3.100000                NaN         1034.699951
# 19282          0.000000                0.0         1016.599976
# 28065          8.900000                0.0         1016.799988
# 36844         11.700000                NaN         1019.400024
# 45614          4.000000                NaN                 NaN
# 54382         10.600000                0.0         1015.700012
# 63060          0.300000                NaN         1017.299988
# 71779         16.700001                0.0         1017.299988
# 80562         12.200000                0.0         1009.000000
# 89342         -0.600000                0.0         1011.500000
# 98020          0.300000                NaN         1017.299988
# 106729         4.300000                NaN         1034.000000
# 115494         3.900000                0.0         1012.799988
# 124276         3.900000                0.0         1015.400024
# 132955        -6.100000                NaN         1017.900024
#
#         wind_direction  wind_speed        timezone country_code  \
# 1735             160.0         3.1      US/Eastern           US
# 10508             30.0         1.5   Europe/London           UK
# 19282             80.0         3.6     US/Mountain           US
# 28065              0.0         0.0      US/Eastern           US
# 36844            170.0         6.2      US/Pacific           US
# 45614             50.0         2.1   Europe/London           UK
# 54382              0.0         0.0      US/Eastern           US
# 63060            310.0         3.6  Canada/Eastern           CA
# 71779            160.0         3.1      US/Eastern           US
# 80562            190.0         1.5      US/Central           US
# 89342            180.0         3.6     US/Mountain           US
# 98020            310.0         3.6  Canada/Eastern           CA
# 106729           160.0         2.0   Europe/Dublin           IE
# 115494           130.0         3.1      US/Central           US
# 124276             0.0         0.0      US/Eastern           US
# 132955           330.0         3.1      US/Eastern           US
#
#                         location            timestamp_local
# 1735                 Orlando, FL  2016-03-13 03:00:00-04:00
# 10508           UK, Southhampton  2016-03-13 07:00:00+00:00
# 19282                  Tempe, AZ  2016-03-13 00:00:00-07:00
# 28065             Washington, WA  2016-03-13 03:00:00-04:00
# 36844          San Francisco, CA  2016-03-12 23:00:00-08:00
# 45614                 UK, London  2016-03-13 07:00:00+00:00
# 54382               Philadelphia  2016-03-13 03:00:00-04:00
# 63060            Montreal/Ottawa  2016-03-13 03:00:00-04:00
# 71779                Orlando, FL  2016-03-13 03:00:00-04:00
# 80562                 Austin, TX  2016-03-13 01:00:00-06:00
# 89342                Ogden, Utah  2016-03-13 00:00:00-07:00
# 98020            Montreal/Ottawa  2016-03-13 03:00:00-04:00
# 106729                   Ireland  2016-03-13 07:00:00+00:00
# 115494  Minneapolis, Twin Cities  2016-03-13 01:00:00-06:00
# 124276       Charlottesville, VA  2016-03-13 03:00:00-04:00
# 132955            Pittsburgh, PA  2016-03-13 03:00:00-04:00

# %%
timezone("US/Mountain")
# Out:
# <DstTzInfo 'US/Mountain' LMT-1 day, 17:00:00 STD>

# %%
# use this function for weather data
# take all columns, maybe use geoloc later
def convert_timestamps(data, site_info):
    data = data.merge(timezones, on = "site_id", how = "left")
    data['timezone'] = data.timezone.apply(lambda x: timezone(x))
    data['timestamp_local'] = data.apply(lambda x: x.timestamp.astimezone(x.timezone), axis = 1)
    data

# %%
# use this function for meter readings
def localize_timestamps(data, site_info):
    data = data.merge(timezones, on = "site_id", how = "left")
    data['timezone'] = data.timezone.apply(lambda x: timezone(x))
    data['timestamp_local'] = data.apply(lambda x: x.timezone.localize(x.timestamp), axis = 1)
    data

# %%
RAW_DATA_DIR = "../data/raw"
train_df = pd.read_csv(RAW_DATA_DIR + "./train.csv")

# %%
building_df = pd.read_csv(RAW_DATA_DIR + "/building_metadata.csv")

# %%
train_df = train_df.merge(building_df, left_on="building_id",
                              right_on="building_id", how="left")

# %%
train_df = train_df.merge(site_info, on = "site_id", how = "left")

# %%
train_df.head()
# Out:
#    building_id  meter            timestamp  meter_reading  site_id  \
# 0            0      0  2016-01-01 00:00:00            0.0        0
# 1            1      0  2016-01-01 00:00:00            0.0        0
# 2            2      0  2016-01-01 00:00:00            0.0        0
# 3            3      0  2016-01-01 00:00:00            0.0        0
# 4            4      0  2016-01-01 00:00:00            0.0        0
#
#   primary_use  square_feet  year_built  floor_count    timezone country_code  \
# 0   Education         7432      2008.0          NaN  US/Eastern           US
# 1   Education         2720      2004.0          NaN  US/Eastern           US
# 2   Education         5376      1991.0          NaN  US/Eastern           US
# 3   Education        23685      2002.0          NaN  US/Eastern           US
# 4   Education       116607      1975.0          NaN  US/Eastern           US
#
#       location
# 0  Orlando, FL
# 1  Orlando, FL
# 2  Orlando, FL
# 3  Orlando, FL
# 4  Orlando, FL

# %%
#train_df['timestamp'] = train_df.timestamp.apply(lambda x: pd.Timestamp(x))

# %%
int(train_df.timestamp[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-de8971d86dc0> in <module>
# ----> 1 int(train_df.timestamp[1])
#
# ValueError: invalid literal for int() with base 10: '2016-01-01 00:00:00'

# %%
train_df['timezone'] = train_df['timezone'].apply(lambda x: timezone(x))

# %%
train_df.timezone[1].localize(train_df.timestamp[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-91c5f79216f6> in <module>
# ----> 1 train_df.timezone[1].localize(train_df.timestamp[1])
#
# c:\users\mufasa\desktop\uni\master biostatistik\git\ashrae-energy-prediction\env\lib\site-packages\pytz\tzinfo.py in localize(self, dt, is_dst)
#     315         Non-existent
#     316         '''
# --> 317         if dt.tzinfo is not None:
#     318             raise ValueError('Not naive datetime (tzinfo is already set)')
#     319
#
# AttributeError: 'str' object has no attribute 'tzinfo'

# %%
#k = [tz.localize(tstamp) for tz,tstamp in train_df['timezone'], train_df['timestamp']]

# %%
train_df['timestamp_local'] = train_df.apply(lambda x: x.timezone.localize(x.timestamp), axis = 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-9835aa6406dc> in <module>
# ----> 1 train_df['timestamp_local'] = train_df.apply(lambda x: x.timezone.localize(x.timestamp), axis = 1)
#
# c:\users\mufasa\desktop\uni\master biostatistik\git\ashrae-energy-prediction\env\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6926             kwds=kwds,
#    6927         )
# -> 6928         return op.get_result()
#    6929
#    6930     def applymap(self, func):
#
# c:\users\mufasa\desktop\uni\master biostatistik\git\ashrae-energy-prediction\env\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# c:\users\mufasa\desktop\uni\master biostatistik\git\ashrae-energy-prediction\env\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# c:\users\mufasa\desktop\uni\master biostatistik\git\ashrae-energy-prediction\env\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# <ipython-input-52-9835aa6406dc> in <lambda>(x)
# ----> 1 train_df['timestamp_local'] = train_df.apply(lambda x: x.timezone.localize(x.timestamp), axis = 1)
#
# c:\users\mufasa\desktop\uni\master biostatistik\git\ashrae-energy-prediction\env\lib\site-packages\pytz\tzinfo.py in localize(self, dt, is_dst)
#     315         Non-existent
#     316         '''
# --> 317         if dt.tzinfo is not None:
#     318             raise ValueError('Not naive datetime (tzinfo is already set)')
#     319
#
# AttributeError: ("'str' object has no attribute 'tzinfo'", 'occurred at index 0')
