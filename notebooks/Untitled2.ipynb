# %%
import pandas as pd

# %%
import seaborn as sns
import warnings
import matplotlib
import gc
warnings.simplefilter('ignore')
matplotlib.rcParams['figure.dpi'] = 100
sns.set()

# %%
import numpy as np

# %%
train = pd.read_csv("../data/raw/train.csv")

# %%
building = pd.read_csv("../data/raw/building_metadata.csv")

# %%
train = train.merge(building, how = "left", on = "building_id")

# %%
train["timestamp"] = pd.to_datetime(train["timestamp"])

# %%
train.head()
# Out:
#    building_id  meter            timestamp  meter_reading  site_id  \
# 0            0      0  2016-01-01 00:00:00            0.0        0
# 1            1      0  2016-01-01 00:00:00            0.0        0
# 2            2      0  2016-01-01 00:00:00            0.0        0
# 3            3      0  2016-01-01 00:00:00            0.0        0
# 4            4      0  2016-01-01 00:00:00            0.0        0
#
#   primary_use  square_feet  year_built  floor_count
# 0   Education         7432      2008.0          NaN
# 1   Education         2720      2004.0          NaN
# 2   Education         5376      1991.0          NaN
# 3   Education        23685      2002.0          NaN
# 4   Education       116607      1975.0          NaN

# %%
drop = train[train["site_id"] == 0]

# %%
drop.head()
# Out:
#    building_id  meter  timestamp  meter_reading  site_id primary_use  \
# 0            0      0 2016-01-01            0.0        0   Education
# 1            1      0 2016-01-01            0.0        0   Education
# 2            2      0 2016-01-01            0.0        0   Education
# 3            3      0 2016-01-01            0.0        0   Education
# 4            4      0 2016-01-01            0.0        0   Education
#
#    square_feet  year_built  floor_count
# 0         7432      2008.0          NaN
# 1         2720      2004.0          NaN
# 2         5376      1991.0          NaN
# 3        23685      2002.0          NaN
# 4       116607      1975.0          NaN

# %%
drop = drop[drop["meter"] == 0]

# %%
drop.head()
# Out:
#    building_id  meter            timestamp  meter_reading  site_id  \
# 0            0      0  2016-01-01 00:00:00            0.0        0
# 1            1      0  2016-01-01 00:00:00            0.0        0
# 2            2      0  2016-01-01 00:00:00            0.0        0
# 3            3      0  2016-01-01 00:00:00            0.0        0
# 4            4      0  2016-01-01 00:00:00            0.0        0
#
#   primary_use  square_feet  year_built  floor_count
# 0   Education         7432      2008.0          NaN
# 1   Education         2720      2004.0          NaN
# 2   Education         5376      1991.0          NaN
# 3   Education        23685      2002.0          NaN
# 4   Education       116607      1975.0          NaN

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(1,1,figsize=(14, 6))
train.groupby('building_id')['meter_reading'].mean().plot();
axes.set_title('Mean meter reading by building_id', fontsize=14);
axes.set_ylabel('Mean meter reading', fontsize=14);

# %%
fig, axes = plt.subplots(1, 1, figsize=(14, 6), dpi=100)
drop[['timestamp', 'meter_reading']].set_index('timestamp').resample('H').mean()['meter_reading'].plot(ax=axes, label='By hour', alpha=0.8).set_ylabel('Meter reading', fontsize=14)
# Out:
# Text(0, 0.5, 'Meter reading')

# %%
building_1099 = train[train["building_id"] == 1099]

# %%
building_1099["hour"] = train["timestamp"].dt.hour

# %%
building_1099.groupby('meter')
# Out:
#        building_id  meter           timestamp  meter_reading  site_id  \
# 1533          1099      0 2016-01-01 00:00:00        282.248       13
# 1534          1099      2 2016-01-01 00:00:00    3241630.000       13
# 3829          1099      0 2016-01-01 01:00:00        282.248       13
# 3830          1099      2 2016-01-01 01:00:00    3241630.000       13
# 6125          1099      0 2016-01-01 02:00:00        284.864       13
# 6126          1099      2 2016-01-01 02:00:00     262584.000       13
# 8424          1099      0 2016-01-01 03:00:00        280.287       13
# 8425          1099      2 2016-01-01 03:00:00      22632.000       13
# 10719         1099      0 2016-01-01 04:00:00        279.975       13
# 10720         1099      2 2016-01-01 04:00:00     160896.000       13
#
#       primary_use  square_feet  year_built  floor_count
# 1533    Education       332884         NaN          NaN
# 1534    Education       332884         NaN          NaN
# 3829    Education       332884         NaN          NaN
# 3830    Education       332884         NaN          NaN
# 6125    Education       332884         NaN          NaN
# 6126    Education       332884         NaN          NaN
# 8424    Education       332884         NaN          NaN
# 8425    Education       332884         NaN          NaN
# 10719   Education       332884         NaN          NaN
# 10720   Education       332884         NaN          NaN

# %%
plot = building_1099.groupby(["hour", "meter"])["meter_reading"].mean().unstack().plot(subplots=True, sort_columns=True, figsize=(4,16))

# %%
m2 = building_1099[building_1099['meter'] == 2]
m0 = building_1099[building_1099['meter'] == 0]

# %%
m0.head()
# Out:
#        building_id  meter           timestamp  meter_reading  site_id  \
# 1533          1099      0 2016-01-01 00:00:00        282.248       13
# 3829          1099      0 2016-01-01 01:00:00        282.248       13
# 6125          1099      0 2016-01-01 02:00:00        284.864       13
# 8424          1099      0 2016-01-01 03:00:00        280.287       13
# 10719         1099      0 2016-01-01 04:00:00        279.975       13
#
#       primary_use  square_feet  year_built  floor_count  hour
# 1533    Education       332884         NaN          NaN     0
# 3829    Education       332884         NaN          NaN     1
# 6125    Education       332884         NaN          NaN     2
# 8424    Education       332884         NaN          NaN     3
# 10719   Education       332884         NaN          NaN     4

# %%
m2.head()
# Out:
#        building_id  meter           timestamp  meter_reading  site_id  \
# 1534          1099      2 2016-01-01 00:00:00      3241630.0       13
# 3830          1099      2 2016-01-01 01:00:00      3241630.0       13
# 6126          1099      2 2016-01-01 02:00:00       262584.0       13
# 8425          1099      2 2016-01-01 03:00:00        22632.0       13
# 10720         1099      2 2016-01-01 04:00:00       160896.0       13
#
#       primary_use  square_feet  year_built  floor_count  hour
# 1534    Education       332884         NaN          NaN     0
# 3830    Education       332884         NaN          NaN     1
# 6126    Education       332884         NaN          NaN     2
# 8425    Education       332884         NaN          NaN     3
# 10720   Education       332884         NaN          NaN     4

# %%
max(m2.meter_reading)
# Out:
# 21904700.0

# %%
fig, axes = plt.subplots(1, 1, figsize=(14, 6), dpi=100)
m2[['timestamp', 'meter_reading']].set_index('timestamp').resample('H').mean()['meter_reading'].plot(ax=axes, alpha=0.8, label='By hour', color='tab:blue').set_ylabel('Mean meter reading', fontsize=14);
m2[['timestamp', 'meter_reading']].set_index('timestamp').resample('D').mean()['meter_reading'].plot(ax=axes, alpha=1, label='By day', color='tab:orange');
axes.set_title('Mean readings building 1099, meter 2', fontsize=14);
axes.legend();

# %%
fig, axes = plt.subplots(1, 1, figsize=(14, 6), dpi=100)
m0[['timestamp', 'meter_reading']].set_index('timestamp').resample('H').mean()['meter_reading'].plot(ax=axes, alpha=0.8, label='By hour', color='tab:blue').set_ylabel('Mean dew temperature', fontsize=14);
m0[['timestamp', 'meter_reading']].set_index('timestamp').resample('D').mean()['meter_reading'].plot(ax=axes, alpha=1, label='By day', color='tab:orange');
axes.set_title('Mean readings building 1099, meter 0', fontsize=14);
axes.legend();

# %%
building_1099[building_1099['meter'] == 2]
# Out:
#           building_id  meter           timestamp  meter_reading  site_id  \
# 1534             1099      2 2016-01-01 00:00:00      3241630.0       13
# 3830             1099      2 2016-01-01 01:00:00      3241630.0       13
# 6126             1099      2 2016-01-01 02:00:00       262584.0       13
# 8425             1099      2 2016-01-01 03:00:00        22632.0       13
# 10720            1099      2 2016-01-01 04:00:00       160896.0       13
# ...               ...    ...                 ...            ...      ...
# 20205861         1099      2 2016-12-31 19:00:00         8688.0       13
# 20208224         1099      2 2016-12-31 20:00:00         8784.0       13
# 20210589         1099      2 2016-12-31 21:00:00         4800.0       13
# 20212956         1099      2 2016-12-31 22:00:00         4896.0       13
# 20215321         1099      2 2016-12-31 23:00:00         5040.0       13
#
#          primary_use  square_feet  year_built  floor_count  hour
# 1534       Education       332884         NaN          NaN     0
# 3830       Education       332884         NaN          NaN     1
# 6126       Education       332884         NaN          NaN     2
# 8425       Education       332884         NaN          NaN     3
# 10720      Education       332884         NaN          NaN     4
# ...              ...          ...         ...          ...   ...
# 20205861   Education       332884         NaN          NaN    19
# 20208224   Education       332884         NaN          NaN    20
# 20210589   Education       332884         NaN          NaN    21
# 20212956   Education       332884         NaN          NaN    22
# 20215321   Education       332884         NaN          NaN    23
#
# [8784 rows x 10 columns]
